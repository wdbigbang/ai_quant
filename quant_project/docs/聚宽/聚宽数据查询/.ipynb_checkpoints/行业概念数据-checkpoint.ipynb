# %%
from jqdatasdk import *
import configparser
 
config = configparser.ConfigParser()
file = 'config.ini'
config.read(file)
user = config.get('login','user')
password = config.get('login','password')
auth(user,password)
# Out:
# auth success （JQData现有流量增加活动，详情请咨询JQData管理员，微信号：JQData02）

# %% [markdown]
# # 行业概念相关API
#
# 提供行业板块信息，概念板块信息，包含行业代码、名称等。
#
# - 获取行业类成份股请使用`get_industry_stocks(industry_code, date=None)`, 详情[见这里](https://www.joinquant.com/api#get_industry_stocks).
# - 获取概念类成分股请使用`get_concept_stocks(concept_code, date=None)`, 详情[见这里](https://www.joinquant.com/api#get_concept_stocks).
# - get_industries [获取行业列表](https://www.joinquant.com/help/api/help?name=api#get_industry_stocks)
#
# - get_concepts [获取概念列表](https://www.joinquant.com/help/api/help?name=api#get_industry_stocks)
#
# - get_industry [查询股票所属行业](https://www.joinquant.com/help/api/help?name=api#get_industry_stocks)
#
# - get_concept [获取股票所属概念板块](https://www.joinquant.com/help/api/help?name=api#get_industry_stocks)
#
#
# - 目前申万行业提供行情数据，频率为天，交易日17:40更新；
# - [获取中证指数/行业的行情,pe,pb,股息率](https://www.joinquant.com/view/community/detail/16656)
# - 概念板块目前没有行情数据；
#
# (温馨提示：鉴于内容太多, 可使用`Ctrl + F`进行搜索)

# %% [markdown]
# ## get_industry_stocks  获取行业成份股
# `get_concept_stocks(concept_code, date=None)`
# 获取在给定日期一个概念板块的所有股票，概念板块分类列表见数据页面-行业概念数据。
#
# **参数**
#
# - concept_code: 概念板块编码
# - date: 查询日期, 一个字符串(格式类似'2015-10-15')或者[datetime.date]/[datetime.datetime]对象, 可以是None, 使用默认日期. 这个默认日期在回测和研究模块上有点差别:
#  - 回测模块: 默认值会随着回测日期变化而变化, 等于context.current_dt
#  - 研究模块: 默认是今天
#
# **返回** 返回股票代码的list
#
# **示例**

# %%
# 获取计算机/互联网行业的成分股
stocks = get_industry_stocks('I64')
print(stocks)
# Out:
# ['000503.XSHE', '000606.XSHE', '000676.XSHE', '000835.XSHE', '002072.XSHE', '002095.XSHE', '002113.XSHE', '002131.XSHE', '002137.XSHE', '002174.XSHE', '002175.XSHE', '002235.XSHE', '002247.XSHE', '002315.XSHE', '002354.XSHE', '002425.XSHE', '002439.XSHE', '002447.XSHE', '002464.XSHE', '002467.XSHE', '002517.XSHE', '002530.XSHE', '002555.XSHE', '002558.XSHE', '002619.XSHE', '002624.XSHE', '300031.XSHE', '300038.XSHE', '300043.XSHE', '300052.XSHE', '300059.XSHE', '300104.XSHE', '300113.XSHE', '300226.XSHE', '300242.XSHE', '300295.XSHE', '300315.XSHE', '300343.XSHE', '300392.XSHE', '300418.XSHE', '300431.XSHE', '300467.XSHE', '300494.XSHE', '300571.XSHE', '300766.XSHE', '300773.XSHE', '300785.XSHE', '600242.XSHG', '600358.XSHG', '600633.XSHG', '600634.XSHG', '600640.XSHG', '600652.XSHG', '600804.XSHG', '600899.XSHG', '600986.XSHG', '601360.XSHG', '603000.XSHG', '603258.XSHG', '603444.XSHG', '603533.XSHG', '603825.XSHG', '603881.XSHG', '603888.XSHG']

# %% [markdown]
# ## get_concept_stocks  获取概念成份股
# `get_concept_stocks(concept_code, date=None)`
# 获取在给定日期一个概念板块的所有股票，概念板块分类列表见数据页面-行业概念数据。
#
# **参数**
#
# - concept_code: 概念板块编码
# - date: 查询日期, 一个字符串(格式类似'2015-10-15')或者[datetime.date]/[datetime.datetime]对象, 可以是None, 使用默认日期. 这个默认日期在回测和研究模块上有点差别:
#   - 回测模块: 默认值会随着回测日期变化而变化, 等于context.current_dt
#   - 研究模块: 默认是今天
# **返回** 返回股票代码的list
#
# **示例**

# %%
# 获取风力发电概念板块的成分股
stocks = get_concept_stocks('GN036', date='2019-04-16')
print(stocks)
# Out:
# ['000791.XSHE', '000836.XSHE', '000862.XSHE', '000958.XSHE', '002080.XSHE', '002202.XSHE', '002204.XSHE', '002531.XSHE', '300040.XSHE', '300129.XSHE', '300169.XSHE', '300185.XSHE', '300443.XSHE', '300569.XSHE', '300690.XSHE', '600163.XSHG', '600192.XSHG', '600290.XSHG', '600416.XSHG', '600458.XSHG', '600483.XSHG', '600875.XSHG', '601016.XSHG', '601218.XSHG', '601558.XSHG', '601619.XSHG', '603063.XSHG', '603693.XSHG']

# %% [markdown]
# ## get_industries  获取行业列表
# `get_industries(name)`
# 按照行业分类获取行业列表。
#
# **参数**
#
# - name: 行业代码， 取值如下：
#   - "sw_l1": 申万一级行业
#   - "sw_l2": 申万二级行业
#   - "sw_l3": 申万三级行业
#   - "jq_l1": 聚宽一级行业
#   - "jq_l2": 聚宽二级行业
#   - "zjw": 证监会行业
#
# **返回值**
#
# - pandas.DataFrame， 各 column 的含义如下:
#   - index: 行业代码
#   - name: 行业名称
#   - start_date: 开始日期

# %%
# 获取申万一级行业列表
get_industries(name='sw_l1').head()
# Out:
#          name start_date
# 801740  国防军工I 2014-02-21
# 801020    采掘I 2004-02-10
# 801110  家用电器I 2004-02-10
# 801160  公用事业I 2004-02-10
# 801060  建筑建材I 2004-02-10

# %% [markdown]
# ## get_concepts  获取概念列表
# `get_concepts()`
# 获取所有的概念板块列表，概念列表见数据页面-[行业概念数据](https://www.joinquant.com/data/dict/plateData)。
#
# **返回值**
#
# - pandas.DataFrame， 各 column 的含义如下:
#   - index: 概念代码
#   - name: 概念名称
#   - start_date: 开始日期

# %%
# 获取概念列表
get_concepts().head()
# Out:
#        name start_date
# GN001  参股金融 2013-12-31
# GN028  智能电网 2013-12-31
# GN030   物联网 2013-12-31
# GN031    重组 2013-12-31
# GN032   迪士尼 2013-12-31

# %% [markdown]
# ## get_industry 查询股票所属行业
# `get_industry(security, date=None)`
# **参数**
#
# - security：标的代码。类型为字符串，形式如"000001.XSHE"；或为包含标的代码字符串的列表，形如["000001.XSHE", "000002.XSHE"]
# - date：查询的日期。类型为字符串，形如"2018-06-01"或"2018-06-01 09:00:00"；或为datetime.datetime对象和datetime.date。*注意传入对象的时分秒将被忽略*。
#
# **返回结果**
#
# 一个dict， key是标的代码。
#
# **示例**

# %%
get_industry(security=['000001.XSHE','000002.XSHE'], date="2018-06-01")
# Out:
# {'000001.XSHE': {'sw_l1': {'industry_code': '801780', 'industry_name': '银行I'},
#   'sw_l2': {'industry_code': '801192', 'industry_name': '银行II'},
#   'sw_l3': {'industry_code': '851911', 'industry_name': '银行III'},
#   'zjw': {'industry_code': 'J66', 'industry_name': '货币金融服务'},
#   'jq_l2': {'industry_code': 'HY493', 'industry_name': '多元化银行指数'},
#   'jq_l1': {'industry_code': 'HY007', 'industry_name': '金融指数'}},
#  '000002.XSHE': {'sw_l1': {'industry_code': '801180', 'industry_name': '房地产I'},
#   'sw_l2': {'industry_code': '801181', 'industry_name': '房地产开发II'},
#   'sw_l3': {'industry_code': '851811', 'industry_name': '房地产开发III'},
#   'zjw': {'industry_code': 'K70', 'industry_name': '房地产业'},
#   'jq_l2': {'industry_code': 'HY509', 'industry_name': '房地产开发指数'},
#   'jq_l1': {'industry_code': 'HY011', 'industry_name': '房地产指数'}}}

# %%
# 将获取到的嵌套dict转为panel
import pandas as pd
panel = pd.Panel(get_industry(security=['000001.XSHE','000002.XSHE'], date="2018-06-01"))
panel
# Out:
# H:\anaconda\lib\site-packages\IPython\core\interactiveshell.py:2963: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <class 'pandas.core.panel.Panel'>
# Dimensions: 2 (items) x 2 (major_axis) x 6 (minor_axis)
# Items axis: 000001.XSHE to 000002.XSHE
# Major_axis axis: industry_code to industry_name
# Minor_axis axis: sw_l1 to jq_l1

# %%
# 提取panel中的数据
panel[:,:,'sw_l1']
# Out:
#               000001.XSHE 000002.XSHE
# industry_code      801780      801180
# industry_name         银行I        房地产I

# %% [markdown]
# ## get_concept 获取股票所属概念板块(jqdatasdk即将上线)
# `get_concept(security, date=None)`
# 获取股票所属概念板块。返回一个dict，key为标的代码，value详见示例。
#
# - security: 标的代码或标的列表
#
# - date: 要查询的日期，日期字符串/date对象/datetime对象，注意传入datetime对象时忽略日内时间
# code是传入的股票代码；多个code返回嵌套的多个字典。 ‘jq_concept’代表聚宽概念； XX是code所在的概念代码； YY是code所在的概念名称。
#
# **示例**

# %%
dict1 = get_concept('000001.XSHE', date='2019-07-15')
print(dict1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-0d508462cc7f> in <module>()
# ----> 1 dict1 = get_concept('000001.XSHE', date='2019-07-15')
#       2 print(dict1)
#
# NameError: name 'get_concept' is not defined

# %% [markdown]
# # **行业类**

# %% [markdown]
# ## 证监会行业

# %% [markdown]
# | 行业代码 | 行业名称                                 | 起始日期   |
# | -------- | ---------------------------------------- | ---------- |
# | A01      | 农业                                     | 1993-09-17 |
# | A02      | 林业                                     | 1996-12-06 |
# | A03      | 畜牧业                                   | 1997-06-11 |
# | A04      | 渔业                                     | 1993-05-07 |
# | A05      | 农、林、牧、渔服务业                     | 1997-05-30 |
# | B06      | 煤炭开采和洗选业                         | 1994-01-06 |
# | B07      | 石油和天然气开采业                       | 1996-06-28 |
# | B08      | 黑色金属矿采选业                         | 1997-07-08 |
# | B09      | 有色金属矿采选业                         | 1996-03-20 |
# | B10      | 非金属矿采选业                           | 2017-05-03 |
# | B11      | 开采辅助活动                             | 2002-02-05 |
# | B12      | 其他采矿业                               | 2012-01-01 |
# | C13      | 农副食品加工业                           | 1993-12-15 |
# | C14      | 食品制造业                               | 1994-08-18 |
# | GN102    | 抗艾滋病           | 2011-03-15 |
# | GN139    | 土地流转           | 2013-12-31 |
# | GN140    | 二胎政策           | 2013-12-31 |
# | GN141    | 民营银行           | 2013-12-31 |
# | GN142    | 养老产业           | 2013-12-31 |
# | GN143    | 尾气治理           | 2013-12-31 |
# | GN144    | 网络彩票           | 2013-12-31 |
# | GN110    | 安防监控           | 2013-12-31 |
# | GN145    | O2O                | 2013-12-31 |
# | GN146    | 第三方支付         | 2013-12-31 |
# | GN147    | 移动互联网入口     | 2013-12-31 |
# | GN138    | 上海自贸区         | 2013-12-31 |
# | GN148    | 民营医院           | 2013-12-31 |
# | GN150    | 油气管网升级       | 2013-12-31 |
# | GN151    | 创投               | 2013-12-31 |
# | GN152    | 粤港澳自贸区       | 2013-12-31 |
# | GN109    | 石墨烯             | 2013-12-31 |
# | GN108    | 涉矿               | 2013-12-31 |
# | GN107    | 黄金珠宝           | 2013-12-31 |
# | GN106    | 浦东新区           | 2013-12-31 |
# | GN105    | 舟山新区           | 2013-12-31 |
# | GN113    | 金融改革           | 2013-12-31 |
# | GN104    | 聚碳酸酯           | 2013-12-31 |
# | GN149    | 油气改革           | 2013-12-31 |
# | GN103    | 氟化工             | 2013-12-31 |
# | GN001    | 参股金融           | 2013-12-31 |
# | GN135    | 电子商务           | 2013-12-31 |
# | GN115    | 中日韩自贸区       | 2013-12-31 |
# | GN116    | 苹果               | 2013-12-31 |
# | GN117    | 三沙               | 2013-12-31 |
# | GN118    | 中朝经济特区       | 2013-12-31 |
# | GN119    | 3D打印             | 2013-12-31 |
# | GN120    | 地热能             | 2013-12-31 |
# | GN121    | 美丽中国           | 2013-12-31 |
# | GN122    | 太赫兹             | 2013-12-31 |
# | GN123    | 智能IC卡           | 2013-12-31 |
# | GN124    | PM2.5              | 2013-12-31 |
# | GN136    | 互联网金融         | 2013-12-31 |
# | GN112    | 宽带提速           | 2013-12-31 |
# | GN126    | 机器人             | 2013-12-31 |
# | GN127    | 食品安全           | 2013-12-31 |
# | GN128    | 4G                 | 2013-12-31 |
# | GN129    | 生物疫苗           | 2013-12-31 |
# | GN130    | LNG                | 2013-12-31 |
# | GN131    | 大数据             | 2013-12-31 |
# | GN132    | 智能物流           | 2013-12-31 |
# | GN133    | 网络安全           | 2013-12-31 |
# | GN134    | 智能穿戴           | 2013-12-31 |
# | GN111    | 文化传媒概念       | 2013-12-31 |
# | GN125    | 污水处理           | 2013-12-31 |
# | GN137    | 智能电视           | 2013-12-31 |
# | GN114    | 充电桩             | 2013-12-31 |
# | GN087    | 卫星导航           | 2013-12-31 |
# | GN079    | 建筑节能           | 2013-12-31 |
# | GN080    | 网络游戏           | 2013-12-31 |
# | GN081    | 上海本地重组       | 2013-12-31 |
# | GN086    | 稀土永磁           | 2013-12-31 |
# | GN088    | 通用航空           | 2013-12-31 |
# | GN089    | 装饰园林           | 2013-12-31 |
# | GN077    | 三网融合           | 2013-12-31 |
# | GN090    | 合同能源管理       | 2013-12-31 |
# | GN092    | 高端装备制造       | 2013-12-31 |
# | GN093    | 智能交通           | 2013-12-31 |
# | GN1070   | 出口型企业         | 2018-03-23 |
# | GN1071   | 地方国企           | 2018-03-23 |
# | GN1073   | 机电产品           | 2018-03-23 |
# | GN1074   | 无感支付           | 2018-03-26 |
# | GN1078   | 苯酚               | 2018-03-26 |
# | GN1075   | 医药连锁           | 2018-03-26 |
# | GN1076   | 参股药明康德       | 2018-03-26 |
# | GN1077   | 无缝钢管           | 2018-03-26 |
# | GN1080   | 南北船合并         | 2018-03-27 |
# | GN1079   | 挖掘机             | 2018-03-27 |
# | GN1081   | 机器视觉           | 2018-03-29 |
# | GN1082   | 盐湖提锂           | 2018-03-29 |
# | GN1085   | CDR概念            | 2018-04-02 |
# | GN1084   | 室内导航           | 2018-04-02 |
# | GN1088   | 崇明生态岛         | 2018-04-04 |
# | GN1087   | 仿制药             | 2018-04-04 |
# | GN1089   | 稀土               | 2018-04-09 |
# | GN1092   | 合资企业           | 2018-04-11 |
# | GN1093   | 知识产权           | 2018-04-11 |
# | GN1094   | 金融开放           | 2018-04-13 |
# | GN1095   | 纯碱               | 2018-04-13 |
# | GN1096   | 硅晶圆             | 2018-04-17 |
# | GN1097   | 云通信             | 2018-04-17 |
# | GN1098   | 高送转预期         | 2018-04-17 |
# | GN1099   | 领涨龙头           | 2018-04-19 |
# | GN1100   | 蔚来汽车           | 2018-04-24 |
# | GN1101   | 沪深港通重仓       | 2018-04-25 |
# | GN1102   | 波音公司           | 2018-04-26 |
# | GN1103   | 扭亏               | 2018-05-02 |
# | GN1104   | 超导               | 2018-05-03 |
# | GN1105   | 大豆               | 2018-05-04 |
# | GN1106   | 摘帽               | 2018-05-08 |
# | GN1107   | 新股               | 2018-05-16 |
# | GN1108   | 棉花               | 2018-05-17 |
# | GN1121   | 广东自贸区         | 2018-05-23 |
# | GN1120   | 陕西自贸区         | 2018-05-23 |
# | GN1119   | 四川自贸区         | 2018-05-23 |
# | GN1118   | 养老金概念         | 2018-05-23 |
# | GN1109   | 化妆品             | 2018-05-23 |
# | GN1116   | 重庆自贸区         | 2018-05-23 |
# | GN1115   | 北京冬奥会         | 2018-05-23 |
# | GN1114   | 超级细菌           | 2018-05-23 |
# | GN1113   | 电子车牌           | 2018-05-23 |
# | GN1112   | 沪伦通             | 2018-05-23 |
# | GN1110   | 油价上调           | 2018-05-23 |
# | GN1117   | 智慧林业           | 2018-05-23 |
# | GN1111   | 钢铁电商           | 2018-05-23 |
# | GN1122   | 电阻               | 2018-05-24 |
# | GN1123   | 纳米               | 2018-05-24 |
# | GN1124   | 葡萄酒             | 2018-05-30 |
# | GN1125   | 家纺               | 2018-05-30 |
# | GN1126   | 破净               | 2018-05-31 |
# | GN1127   | 云存储             | 2018-06-05 |
# | GN1128   | 电子纸             | 2018-06-06 |
# | GN1130   | 触板               | 2018-06-13 |
# | GN1129   | 抖音概念           | 2018-06-13 |
# | GN1131   | 二极管             | 2018-06-15 |
# | GN1132   | 百度概念           | 2018-06-15 |
# | GN1133   | 成交主力           | 2018-06-21 |
# | GN1135   | 低价股             | 2018-06-25 |
# | GN1134   | 高价股             | 2018-06-25 |
# | GN1136   | 品牌龙头           | 2018-07-04 |
# | GN1137   | 股票回购           | 2018-07-09 |
# | GN1138   | 汇金概念           | 2018-07-10 |
# | GN1139   | 聚酰亚胺           | 2018-07-18 |
# | GN1140   | 富勒烯             | 2018-07-18 |
# | GN1159   | 社保重仓           | 2018-07-19 |
# | GN1141   | 基金重仓           | 2018-07-19 |
# | GN1142   | 超级高铁           | 2018-07-20 |
# | GN1143   | Facebook概念       | 2018-07-25 |
# | GN1145   | 西部大基建         | 2018-08-01 |
# | GN1144   | 中国国际进口博览会 | 2018-08-01 |
# | GN1147   | 宠物食品           | 2018-08-03 |
# | GN1146   | 谷歌概念           | 2018-08-03 |
# | GN1148   | 无效82             | 2018-08-06 |
# | GN1149   | 大基建央企         | 2018-08-10 |
# | GN1150   | 网络可视化         | 2018-08-13 |
# | GN1151   | 多肽药             | 2018-08-15 |
# | GN1152   | 双百企业           | 2018-08-15 |
# | GN1153   | PTA                | 2018-08-21 |
# | GN1154   | 锦纶               | 2018-08-22 |
# | GN1155   | 涤纶               | 2018-08-22 |
# | GN1157   | 子弹短信           | 2018-08-30 |
# | GN1158   | QFII重仓           | 2018-08-30 |
# | GN1160   | 月饼               | 2018-09-10 |
# | GN1161   | 中非合作概念       | 2018-09-11 |
# | GN1162   | 尿素               | 2018-09-14 |
# | GN1164   | 电路板             | 2018-09-26 |
# | GN1165   | 富时罗素概念       | 2018-09-27 |
# | GN1166   | 中远海运集团       | 2018-10-08 |
# | GN1167   | 制造业单项冠军企业 | 2018-10-09 |
# | GN1168   | 宝马概念           | 2018-10-16 |
# | GN1169   | 系统重要性金融机构 | 2018-10-16 |
# | GN1170   | 国资入股           | 2018-10-18 |
# | GN1171   | 低价小市值         | 2018-11-13 |
# | GN1172   | 民营企业           | 2018-11-13 |
# | GN1173   | 广电系             | 2018-11-28 |
# | GN1174   | 标普道琼斯概念     | 2018-12-07 |
# | GN1175   | 券商重仓           | 2018-12-24 |
# | GN1177   | 信托重仓           | 2019-01-14 |
# | GN1178   | 私募重仓           | 2019-01-16 |
# | GN1179   | 磷化工             | 2019-01-18 |
# | GN1180   | 一号文件           | 2019-01-22 |
# | GN1181   | 生态农业           | 2019-01-22 |
# | GN1182   | 供销社             | 2019-01-28 |
# | GN1183   | 业绩爆雷           | 2019-01-30 |
# | GN1184   | 纳米银             | 2019-02-21 |
# | GN1185   | 工业大麻           | 2019-02-22 |
# | GN1186   | 生物质能           | 2019-03-01 |
# | GN1187   | 边缘计算           | 2019-03-04 |
# | GN1188   | 参股科创板         | 2019-03-05 |
# | GN1189   | MSCI中盘           | 2019-03-06 |
# | GN1190   | 纸电池             | 2019-03-08 |
# | GN1191   | 泛在电力物联网     | 2019-03-11 |
# | GN1192   | 数字孪生           | 2019-03-13 |
# | GN1193   | 网络切片           | 2019-03-14 |
# | GN1194   | 电子烟             | 2019-03-18 |
# | GN1195   | 西安自贸区         | 2019-03-21 |
# | GN1196   | 安全生产           | 2019-03-25 |
# | GN1197   | 流媒体             | 2019-03-26 |
# | GN1199   | 参股外资券商       | 2019-04-01 |
# | GN1198   | 国美系             | 2019-04-01 |
# | GN1200   | 横琴旅游岛         | 2019-04-02 |
# | GN1202   | 长三角自贸区       | 2019-04-11 |
# | GN1203   | 醋酸               | 2019/4/15  |
# | GN1204   | 宁夏基建           | 2019/4/15  |
# | GN1205   | 陆股通日买入前二十 | 2019/4/16  |
# | GN1206   | 陆股通日卖出前二十 | 2019/4/18  |
# | GN1207   | 陆股通日增仓前二十 | 2019/4/18  |
# | GN1208   | 陆股通日减仓前二十 | 2019/4/18  |
# | GN1209   | 陆股通周卖出前二十 | 2019/4/19  |
# | GN1217   | 陆股通周买入前二十 | 2019/4/19  |
# | GN1222   | 陆股通周增仓前二十 | 2019/4/22  |
# | GN1213   | 陆股通周减仓前二十 | 2019/4/22  |
# | GN1215   | 陆股通月买入前二十 | 2019/4/22  |
# | GN1220   | 陆股通月卖出前二十 | 2019/4/22  |
# | GN1212   | 陆股通月减仓前二十 | 2019/4/23  |
# | GN1210   | 陆股通月增仓前二十 | 2019/4/23  |
# | GN1214   | 陆股通持续净买入   | 2019/4/24  |
# | GN1219   | 陆股通持续净卖出   | 2019/4/24  |
# | GN1211   | 陆股通增仓         | 2019/4/25  |
# | GN1221   | 陆股通减仓         | 2019/4/25  |
# | GN1216   | 陆股通建仓         | 2019/4/26  |
# | GN1218   | 陆股通清仓         | 2019/4/26  |
# | GN1223   | 机构大额买入       | 2019/4/28  |
# | GN1224   | 机构大额卖出       | 2019/4/28  |

# %% [markdown]
# # 获取行业指数数据

# %% [markdown]
# ## 获取申万一级行业日行情数据

# %% [markdown]
# from jqdatasdk import finance
# df=finance.run_query(query(finance.SW1_DAILY_PRICE).filter(finance.SW1_DAILY_PRICE.code=='801010').limit(n))
# print(df)
# 记录了申万一级行业指数的历史日行情数据，每日18:00更新。
#
# **参数：**
#
# query(finance.SW1_DAILY_PRICE)：表示从finance.SW1_DAILY_PRICE这张表中查询申万一级行业指数的历史日行情数据，还可以指定所要查询的字段名，格式如下：query(库名.表名.字段名1，库名.表名.字段名2），多个字段用英文逗号分隔进行提取；如query(finance.SW1_DAILY_PRICE.code)。query函数的更多用法详见：query简易教程。
# finance.SW1_DAILY_PRICE：代表申万一级行业日行情数据表，收录了申万一级行业指数的历史日行情数据，表结构和字段信息如下：

# %% [markdown]
# | 字段名称   | 中文名称   | 字段类型      | 能否为空 | 注释                           |
# | ---------- | ---------- | ------------- | -------- | ------------------------------ |
# | date       | 交易日     | date          | N        |                                |
# | code       | 指数编码   | varchar(12)   | N        | 对应申万一级行业指数编码       |
# | name       | 指数名称   | varchar(20)   | N        |                                |
# | open       | 开盘指数   | decimal(20,4) |          |                                |
# | high       | 最高指数   | decimal(20,4) |          |                                |
# | low        | 最低指数   | decimal(20,4) |          |                                |
# | close      | 收盘指数   | decimal(20,4) |          |                                |
# | pre_close  | 昨收盘指数 | decimal(20,4) |          | 昨收盘指数用昨日的收盘指数填充 |
# | volume     | 成交量     | decimal(20,4) |          | 单位：股                       |
# | money      | 成交额     | decimal(20,4) |          | 单位：元                       |
# | change_pct | 涨跌幅     | decimal(10,4) |          | 单位：％                       |

# %% [markdown]
# filter(finance.SW1_DAILY_PRICE.code==801010)：指定筛选条件，通过finance.SW1_DAILY_PRICE.code==801010可以查询指定行业（如农林牧渔801010）的日行情数据；除此之外，还可以对表中其他字段指定筛选条件，如finance.SW1_DAILY_PRICE.date=='2019-03-01'，指定获取2019年3月1日的申万一级行业日行情数据。
# limit(n)：限制返回的数据条数，n指定返回条数。
#
# **返回结果：**
#
# 返回一个 dataframe，每一行对应数据表中的一条数据， 列索引是您所查询的字段名称
#
# **注意：**
#
# 1. 为了防止返回数据量过大, 我们每次最多返回3000行
# 2. 不能进行连表查询，即同时查询多张表的数据
#
# **示例：**

# %%
# 查询最近10个交易日申万一级行业指数-农林牧渔行业（801010）的日行情数据。
# from jqdatasdk import finance
df=finance.run_query(query(finance.SW1_DAILY_PRICE).filter(finance.SW1_DAILY_PRICE.code=='801010').order_by(finance.SW1_DAILY_PRICE.date.desc()).limit(10))
print(df.head())
# Out:
#         id        date    code  name     open     high      low    close  \
# 0  1782018  2019-07-24  801010  农林牧渔  3390.01  3420.87  3375.22  3403.73
# 1  1781486  2019-07-23  801010  农林牧渔  3357.65  3386.37  3344.67  3378.28
# 2  1780954  2019-07-22  801010  农林牧渔  3448.30  3448.30  3351.57  3354.49
# 3  1780422  2019-07-19  801010  农林牧渔  3435.11  3486.11  3433.94  3463.47
# 4  1779890  2019-07-18  801010  农林牧渔  3441.27  3476.06  3429.01  3429.01
#
#          volume         money  change_pct
# 0  1.230905e+09  1.294780e+10        0.75
# 1  8.635670e+08  1.077070e+10        0.71
# 2  1.362378e+09  1.609689e+10       -3.15
# 3  1.324605e+09  1.517428e+10        1.00
# 4  1.506355e+09  1.817348e+10       -1.00

# %% [markdown]
# ## 获取申万一级行业估值数据
# from jqdatasdk import finance
# df=finance.run_query(query(finance.SW1_DAILY_VALUATION).filter(finance.SW1_DAILY_VALUATION.code=='801010').limit(n))
# print(df)
# 记录了申万一级行业指数的每日估值数据，每天18:00更新。
#
# **参数：**
#
# query(finance.SW1_DAILY_VALUATION)：表示从finance.SW1_DAILY_VALUATION这张表中查询申万一级行业指数的估值数据，还可以指定所要查询的字段名，格式如下：query(库名.表名.字段名1，库名.表名.字段名2），多个字段用英文逗号分隔进行提取；如query(finance.SW1_DAILY_VALUATION.code)。query函数的更多用法详见：query简易教程。
# finance.SW1_DAILY_VALUATION：代表申万一级行业指数估值表，收录了申万一级行业指数的历史估值数据，表结构和字段信息如下：

# %% [markdown]
# | 字段名称                       | 中文名称     | 字段类型      | 能否为空 | 注释                                                         |
# | ------------------------------ | ------------ | ------------- | -------- | ------------------------------------------------------------ |
# | date                           | 交易日       | date          | N        |                                                              |
# | code                           | 指数编码     | varchar(12)   | N        | 对应申万一级行业指数编码                                     |
# | name                           | 指数名称     | varchar(20)   | N        |                                                              |
# | turnover_ratio                 | 换手率       | decimal(10,4) |          | 单位：％                                                     |
# | pe                             | 市盈率       | decimal(20,4) |          | 单位：倍；PE = 流通市值／最近4个季度的净利润；最近 4 个季度的净利润按如下方法计算: 1-4 月,最近 4 个季度的净利润=上一年度前 3 季度累计净利润+上上一年度的四季度净利润；5-8 月,最近 4 个季度的净利润=当年 1 季度净利润+前 1 年净利润-前 1 年 1 季度净利润；9-10 月,最近 4 个季度的净利润=当年中期净利润+前 1 年净利润-前 1 年中期净利润；11-12 月,最近 4 个季度的净利润=当年前 3 季度累计净利润+上1年年度净利润-上 1 年前 3 季度累计净利润 |
# | pb                             | 市净率       | decimal(20,4) |          | 单位：倍；按照自由流通量加权的净资产倍率。 PB = 流通市值／按照流通市值计算的净资产；按照流通市值计算的净资产 ＝ 最新净资产*流通股本／总股本 |
# | average_price                  | 均价         | decimal(20,4) |          | 单位：元。指数成份股在统计期最后交易日收盘的简单算术平均价   |
# | money_ratio                    | 成交额占比   | decimal(10,4) |          | 单位：％；成交额占比＝某个行业成交额／所有行业成交额之和     |
# | circulating_market_cap         | 流通市值     | decimal(20,4) |          | 单位：元                                                     |
# | average_circulating_market_cap | 平均流通市值 | decimal(20,4) |          | 单位：元；平均流通市值＝流通市值／所在行业股票数             |
# | dividend_ratio                 | 股息率       | decimal(10,4) |          | 单位：％；按照自由流通量加权的现金股息率；dividend_ratio=Df/Vf；Df: 所有股票在截止日的一 个自然年(365日)中所累积派发的税前现金红利之和按照流通股本对应的分红量；Vf: 该行业成分股股的流通市值之和 |

# %% [markdown]
# filter(finance.SW1_DAILY_VALUATION.code==801010)：指定筛选条件，通过finance.SW1_DAILY_VALUATION.code=='801010'可以查询指定行业（如农林牧渔801010）的估值数据；除此之外，还可以对表中其他字段指定筛选条件，如finance.SW1_DAILY_VALUATION.date=='2019-03-01'，指定获取2019年3月1日的申万一级行业的估值数据。
# limit(n)：限制返回的数据条数，n指定返回条数。
#
# **返回结果：**
#
# 返回一个 dataframe，每一行对应数据表中的一条数据， 列索引是您所查询的字段名称
#
# **注意：**
#
# 1. 为了防止返回数据量过大, 我们每次最多返回3000行
# 2. 不能进行连表查询，即同时查询多张表的数据
#
# **示例：**

# %%
# 查询最近10个交易日申万一级行业指数-农林牧渔行业（801010）的估值数据
# from jqdatasdk import finance
df=finance.run_query(query(finance.SW1_DAILY_VALUATION).filter(finance.SW1_DAILY_VALUATION.code=='801010').order_by(finance.SW1_DAILY_VALUATION.date.desc()).limit(10))
print(df.head())
# Out:
#         id        date    code  name  turnover_ratio     pe    pb  \
# 0  1517210  2019-07-24  801010  农林牧渔          1.8149  52.21  3.95
# 1  1516494  2019-07-23  801010  农林牧渔          1.2733  51.83  3.92
# 2  1515778  2019-07-22  801010  农林牧渔          2.0087  51.56  3.89
# 3  1515062  2019-07-19  801010  农林牧渔          1.9531  53.23  4.01
# 4  1514346  2019-07-18  801010  农林牧渔          2.2213  52.71  3.97
#
#    average_price  money_ratio  circulating_market_cap  \
# 0          12.30         3.44            8.526449e+11
# 1          12.18         3.59            8.462207e+11
# 2          12.05         4.41            8.402183e+11
# 3          12.51         4.35            8.681311e+11
# 4          12.47         5.01            8.608687e+11
#
#    average_circulating_market_cap  dividend_ratio
# 0                    1.003112e+10            0.95
# 1                    9.955538e+09            0.95
# 2                    9.884922e+09            0.96
# ...
